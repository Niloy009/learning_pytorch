# %%
import torch
from torch import nn
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from torchmetrics.classification import BinaryAccuracy

# %% [markdown]
# ## Device Afgnostic Code

# %%
# Device agnostic code
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
# !nvidia-smi
# Out:
# Wed Jan 29 01:22:48 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1050 Ti     Off | 00000000:01:00.0  On |                  N/A |
# | N/A   41C    P8              N/A /  16W |    139MiB /  4096MiB |     13%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1360      G   /usr/lib/xorg/Xorg                           45MiB |
# |    0   N/A  N/A    288298      C   ...loy/anaconda3/envs/torch/bin/python       90MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Make the dataset and split it in 80-20 fromat (Tensor)

# %%
# Setup the hyperparameter
N_SAMPLE = 1000
RANDOM_SEED = 42

X_moon, y_moon = make_moons(n_samples=N_SAMPLE, noise=0.07, random_state=RANDOM_SEED)

X_moon[:10], y_moon[:10]
# Out:
# (array([[-0.03341062,  0.4213911 ],
#         [ 0.99882703, -0.4428903 ],
#         [ 0.88959204, -0.32784256],
#         [ 0.34195829, -0.41768975],
#         [-0.83853099,  0.53237483],
#         [ 0.59906425, -0.28977331],
#         [ 0.29009023, -0.2046885 ],
#         [-0.03826868,  0.45942924],
#         [ 1.61377123, -0.2939697 ],
#         [ 0.693337  ,  0.82781911]]),
#  array([1, 1, 1, 1, 0, 1, 1, 1, 1, 0]))

# %%
# Visualize the data
plt.figure(figsize=(10,7))
plt.scatter(X_moon[:, 0], 
            X_moon[:, 1], 
            c=y_moon, 
            cmap=plt.cm.RdYlGn)
plt.show()

# %%
# Make the data into tensor
X_moon = torch.from_numpy(X_moon).type(torch.float)
y_moon = torch.from_numpy(y_moon).type(torch.float)

# %%
#Split the dataset into train (80%) & test (20%)
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(X_moon, 
                                                                         y_moon, 
                                                                         test_size=0.2, 
                                                                         random_state=RANDOM_SEED)

# %%
# Print the train and test data features and labels shape
print(f"The length of train data features: {len(X_moon_train)} & The shape of test data feature: {len(X_moon_test)}")
print(f"The length of train data labels: {len(y_moon_train)} & The shape of test data feature: {len(y_moon_test)}")
# Out:
# The length of train data features: 800 & The shape of test data feature: 200
# The length of train data labels: 800 & The shape of test data feature: 200

# %% [markdown]
# ## Build the Model by subclassing `nn.Module`

# %%
# Setup Model 
class MakeMoonModelV0(nn.Module):
    def __init__(self, input_features:int, output_features:int, hidden_units:int):
        """Initialize of the binary classification model

        Args:
          input_features (int): Number of the features
          output_features (int): Number of the output
          hidden_units (int): Number of hidden units. (default: 8)
        
        Returns:

        Example:
        """
        super().__init__()
        self.linear_stack = nn.Sequential(
            nn.Linear(in_features=input_features, out_features=hidden_units),
            nn.ReLU(),
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.ReLU(),
            nn.Linear(in_features=hidden_units, out_features=output_features)
        )
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.linear_stack(x)


# Create model instance and transfer to the device
model_0 = MakeMoonModelV0(input_features=2, 
                          output_features=1, 
                          hidden_units=8).to(device)

model_0
# Out:
# MakeMoonModelV0(
#   (linear_stack): Sequential(
#     (0): Linear(in_features=2, out_features=8, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=8, out_features=8, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=8, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## Loss function, Optimizer & Accuracy

# %%
# loss function and optimizer and metric (BinaryAccuracy)
loss_fn = nn.BCEWithLogitsLoss()

optimizer = torch.optim.SGD(params=model_0.parameters(), 
                            lr=0.1)
accuracy = BinaryAccuracy().to(device)

# %% [markdown]
# ## Train the model and Test

# %%
# setup the manual seed
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)

epochs = 1000

# Send the data to the device
X_moon_train, y_moon_train = X_moon_train.to(device), y_moon_train.to(device)
X_moon_test, y_moon_test = X_moon_test.to(device), y_moon_test.to(device)

for epoch in range(epochs):
    model_0.train()

    train_moon_logits = model_0(X_moon_train).squeeze()
    train_moon_preds = torch.round(torch.sigmoid(train_moon_logits))

    train_loss = loss_fn(train_moon_logits, y_moon_train)
    train_accuracy = accuracy(train_moon_preds, y_moon_train) * 100

    optimizer.zero_grad()

    train_loss.backward()

    optimizer.step()

    ## Testing
    model_0.eval()
    with torch.inference_mode():
        test_moon_logits = model_0(X_moon_test).squeeze()
        test_moon_preds = torch.round(torch.sigmoid(test_moon_logits))

        test_loss = loss_fn(test_moon_logits, y_moon_test)
        test_accuracy = accuracy(test_moon_preds, y_moon_test) * 100
    if epoch % 10 == 0:
        print(f"Epoch: {epoch} | Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}% | Test loss: {test_loss:.4f}, Test acc: {test_accuracy:.2f}%")
# Out:
# Epoch: 0 | Train Loss: 0.6956, Train Acc: 50.00% | Test loss: 0.6950, Test acc: 50.00%
# Epoch: 10 | Train Loss: 0.6864, Train Acc: 50.00% | Test loss: 0.6862, Test acc: 50.00%
# Epoch: 20 | Train Loss: 0.6802, Train Acc: 78.25% | Test loss: 0.6808, Test acc: 78.50%
# Epoch: 30 | Train Loss: 0.6720, Train Acc: 74.88% | Test loss: 0.6734, Test acc: 68.50%
# Epoch: 40 | Train Loss: 0.6605, Train Acc: 71.62% | Test loss: 0.6629, Test acc: 64.50%
# Epoch: 50 | Train Loss: 0.6444, Train Acc: 71.88% | Test loss: 0.6483, Test acc: 68.00%
# Epoch: 60 | Train Loss: 0.6227, Train Acc: 72.25% | Test loss: 0.6288, Test acc: 69.00%
# Epoch: 70 | Train Loss: 0.5958, Train Acc: 73.50% | Test loss: 0.6047, Test acc: 70.00%
# Epoch: 80 | Train Loss: 0.5660, Train Acc: 74.62% | Test loss: 0.5778, Test acc: 71.50%
# Epoch: 90 | Train Loss: 0.5357, Train Acc: 76.25% | Test loss: 0.5498, Test acc: 72.50%
# Epoch: 100 | Train Loss: 0.5064, Train Acc: 78.50% | Test loss: 0.5224, Test acc: 74.00%
# Epoch: 110 | Train Loss: 0.4791, Train Acc: 79.50% | Test loss: 0.4962, Test acc: 76.50%
# Epoch: 120 | Train Loss: 0.4541, Train Acc: 80.38% | Test loss: 0.4714, Test acc: 78.00%
# Epoch: 130 | Train Loss: 0.4317, Train Acc: 82.00% | Test loss: 0.4486, Test acc: 79.50%
# Epoch: 140 | Train Loss: 0.4118, Train Acc: 82.75% | Test loss: 0.4278, Test acc: 81.50%
# Epoch: 150 | Train Loss: 0.3938, Train Acc: 83.50% | Test loss: 0.4085, Test acc: 83.00%
# Epoch: 160 | Train Loss: 0.3775, Train Acc: 84.25% | Test loss: 0.3908, Test acc: 83.50%
# Epoch: 170 | Train Loss: 0.3629, Train Acc: 85.00% | Test loss: 0.3747, Test acc: 84.00%
# Epoch: 180 | Train Loss: 0.3496, Train Acc: 85.25% | Test loss: 0.3600, Test acc: 84.00%
# Epoch: 190 | Train Loss: 0.3376, Train Acc: 85.62% | Test loss: 0.3466, Test acc: 84.50%
# Epoch: 200 | Train Loss: 0.3268, Train Acc: 86.00% | Test loss: 0.3345, Test acc: 85.50%
# Epoch: 210 | Train Loss: 0.3173, Train Acc: 86.75% | Test loss: 0.3239, Test acc: 85.50%
# Epoch: 220 | Train Loss: 0.3091, Train Acc: 87.25% | Test loss: 0.3146, Test acc: 86.00%
# Epoch: 230 | Train Loss: 0.3019, Train Acc: 87.25% | Test loss: 0.3065, Test acc: 87.00%
# Epoch: 240 | Train Loss: 0.2956, Train Acc: 87.38% | Test loss: 0.2993, Test acc: 88.50%
# Epoch: 250 | Train Loss: 0.2902, Train Acc: 87.50% | Test loss: 0.2930, Test acc: 89.00%
# Epoch: 260 | Train Loss: 0.2855, Train Acc: 87.62% | Test loss: 0.2875, Test acc: 89.00%
# Epoch: 270 | Train Loss: 0.2814, Train Acc: 87.88% | Test loss: 0.2826, Test acc: 89.00%
# Epoch: 280 | Train Loss: 0.2778, Train Acc: 88.00% | Test loss: 0.2783, Test acc: 89.00%
# Epoch: 290 | Train Loss: 0.2747, Train Acc: 88.12% | Test loss: 0.2746, Test acc: 89.00%
# Epoch: 300 | Train Loss: 0.2719, Train Acc: 88.12% | Test loss: 0.2712, Test acc: 89.00%
# Epoch: 310 | Train Loss: 0.2694, Train Acc: 88.25% | Test loss: 0.2682, Test acc: 89.00%
# Epoch: 320 | Train Loss: 0.2672, Train Acc: 88.38% | Test loss: 0.2656, Test acc: 89.50%
# Epoch: 330 | Train Loss: 0.2651, Train Acc: 88.25% | Test loss: 0.2632, Test acc: 89.50%
# Epoch: 340 | Train Loss: 0.2633, Train Acc: 88.25% | Test loss: 0.2610, Test acc: 89.50%
# Epoch: 350 | Train Loss: 0.2615, Train Acc: 88.38% | Test loss: 0.2590, Test acc: 89.50%
# Epoch: 360 | Train Loss: 0.2600, Train Acc: 88.38% | Test loss: 0.2571, Test acc: 89.50%
# Epoch: 370 | Train Loss: 0.2585, Train Acc: 88.38% | Test loss: 0.2554, Test acc: 89.50%
# Epoch: 380 | Train Loss: 0.2572, Train Acc: 88.38% | Test loss: 0.2538, Test acc: 89.50%
# Epoch: 390 | Train Loss: 0.2559, Train Acc: 88.38% | Test loss: 0.2523, Test acc: 89.50%
# Epoch: 400 | Train Loss: 0.2547, Train Acc: 88.50% | Test loss: 0.2509, Test acc: 90.00%
# Epoch: 410 | Train Loss: 0.2535, Train Acc: 88.50% | Test loss: 0.2495, Test acc: 90.00%
# Epoch: 420 | Train Loss: 0.2524, Train Acc: 88.50% | Test loss: 0.2482, Test acc: 90.00%
# Epoch: 430 | Train Loss: 0.2513, Train Acc: 88.62% | Test loss: 0.2469, Test acc: 90.00%
# Epoch: 440 | Train Loss: 0.2502, Train Acc: 88.75% | Test loss: 0.2457, Test acc: 90.00%
# Epoch: 450 | Train Loss: 0.2491, Train Acc: 88.75% | Test loss: 0.2445, Test acc: 90.00%
# Epoch: 460 | Train Loss: 0.2481, Train Acc: 88.75% | Test loss: 0.2433, Test acc: 90.00%
# Epoch: 470 | Train Loss: 0.2470, Train Acc: 88.75% | Test loss: 0.2422, Test acc: 90.00%
# Epoch: 480 | Train Loss: 0.2459, Train Acc: 88.75% | Test loss: 0.2410, Test acc: 90.00%
# Epoch: 490 | Train Loss: 0.2448, Train Acc: 88.75% | Test loss: 0.2398, Test acc: 90.00%
# Epoch: 500 | Train Loss: 0.2438, Train Acc: 88.75% | Test loss: 0.2386, Test acc: 90.00%
# Epoch: 510 | Train Loss: 0.2426, Train Acc: 88.75% | Test loss: 0.2374, Test acc: 90.00%
# Epoch: 520 | Train Loss: 0.2415, Train Acc: 88.75% | Test loss: 0.2362, Test acc: 90.00%
# Epoch: 530 | Train Loss: 0.2403, Train Acc: 88.75% | Test loss: 0.2350, Test acc: 90.00%
# Epoch: 540 | Train Loss: 0.2391, Train Acc: 88.75% | Test loss: 0.2337, Test acc: 90.00%
# Epoch: 550 | Train Loss: 0.2379, Train Acc: 88.75% | Test loss: 0.2324, Test acc: 90.50%
# Epoch: 560 | Train Loss: 0.2366, Train Acc: 88.75% | Test loss: 0.2311, Test acc: 90.50%
# Epoch: 570 | Train Loss: 0.2353, Train Acc: 88.75% | Test loss: 0.2297, Test acc: 90.50%
# Epoch: 580 | Train Loss: 0.2339, Train Acc: 88.75% | Test loss: 0.2283, Test acc: 90.00%
# Epoch: 590 | Train Loss: 0.2325, Train Acc: 89.12% | Test loss: 0.2268, Test acc: 90.00%
# Epoch: 600 | Train Loss: 0.2309, Train Acc: 89.25% | Test loss: 0.2253, Test acc: 90.00%
# Epoch: 610 | Train Loss: 0.2293, Train Acc: 89.38% | Test loss: 0.2237, Test acc: 90.00%
# Epoch: 620 | Train Loss: 0.2276, Train Acc: 89.38% | Test loss: 0.2221, Test acc: 90.00%
# Epoch: 630 | Train Loss: 0.2259, Train Acc: 89.62% | Test loss: 0.2204, Test acc: 90.00%
# Epoch: 640 | Train Loss: 0.2241, Train Acc: 89.88% | Test loss: 0.2186, Test acc: 90.00%
# Epoch: 650 | Train Loss: 0.2222, Train Acc: 89.88% | Test loss: 0.2168, Test acc: 90.00%
# Epoch: 660 | Train Loss: 0.2202, Train Acc: 89.88% | Test loss: 0.2149, Test acc: 90.00%
# Epoch: 670 | Train Loss: 0.2182, Train Acc: 89.88% | Test loss: 0.2129, Test acc: 90.50%
# Epoch: 680 | Train Loss: 0.2160, Train Acc: 90.00% | Test loss: 0.2108, Test acc: 90.50%
# Epoch: 690 | Train Loss: 0.2137, Train Acc: 90.25% | Test loss: 0.2087, Test acc: 90.50%
# Epoch: 700 | Train Loss: 0.2113, Train Acc: 90.25% | Test loss: 0.2064, Test acc: 90.50%
# Epoch: 710 | Train Loss: 0.2089, Train Acc: 90.25% | Test loss: 0.2041, Test acc: 91.00%
# Epoch: 720 | Train Loss: 0.2063, Train Acc: 90.25% | Test loss: 0.2016, Test acc: 91.50%
# Epoch: 730 | Train Loss: 0.2037, Train Acc: 90.38% | Test loss: 0.1991, Test acc: 91.50%
# Epoch: 740 | Train Loss: 0.2008, Train Acc: 90.75% | Test loss: 0.1965, Test acc: 91.50%
# Epoch: 750 | Train Loss: 0.1979, Train Acc: 91.12% | Test loss: 0.1937, Test acc: 92.00%
# Epoch: 760 | Train Loss: 0.1949, Train Acc: 91.38% | Test loss: 0.1909, Test acc: 92.00%
# Epoch: 770 | Train Loss: 0.1918, Train Acc: 91.38% | Test loss: 0.1880, Test acc: 92.00%
# Epoch: 780 | Train Loss: 0.1885, Train Acc: 91.50% | Test loss: 0.1849, Test acc: 92.00%
# Epoch: 790 | Train Loss: 0.1852, Train Acc: 91.62% | Test loss: 0.1816, Test acc: 92.00%
# Epoch: 800 | Train Loss: 0.1817, Train Acc: 92.00% | Test loss: 0.1781, Test acc: 92.50%
# Epoch: 810 | Train Loss: 0.1782, Train Acc: 92.38% | Test loss: 0.1745, Test acc: 92.50%
# Epoch: 820 | Train Loss: 0.1745, Train Acc: 92.50% | Test loss: 0.1708, Test acc: 92.50%
# Epoch: 830 | Train Loss: 0.1708, Train Acc: 92.75% | Test loss: 0.1671, Test acc: 93.00%
# Epoch: 840 | Train Loss: 0.1670, Train Acc: 93.00% | Test loss: 0.1633, Test acc: 93.00%
# Epoch: 850 | Train Loss: 0.1631, Train Acc: 93.00% | Test loss: 0.1593, Test acc: 93.00%
# Epoch: 860 | Train Loss: 0.1591, Train Acc: 93.62% | Test loss: 0.1553, Test acc: 93.50%
# Epoch: 870 | Train Loss: 0.1551, Train Acc: 93.62% | Test loss: 0.1512, Test acc: 93.50%
# Epoch: 880 | Train Loss: 0.1511, Train Acc: 93.75% | Test loss: 0.1471, Test acc: 94.00%
# Epoch: 890 | Train Loss: 0.1470, Train Acc: 93.75% | Test loss: 0.1429, Test acc: 94.50%
# Epoch: 900 | Train Loss: 0.1429, Train Acc: 93.75% | Test loss: 0.1386, Test acc: 95.00%
# Epoch: 910 | Train Loss: 0.1388, Train Acc: 94.25% | Test loss: 0.1343, Test acc: 96.00%
# Epoch: 920 | Train Loss: 0.1346, Train Acc: 94.25% | Test loss: 0.1299, Test acc: 96.50%
# Epoch: 930 | Train Loss: 0.1305, Train Acc: 94.62% | Test loss: 0.1256, Test acc: 96.50%
# Epoch: 940 | Train Loss: 0.1264, Train Acc: 94.88% | Test loss: 0.1213, Test acc: 97.00%
# Epoch: 950 | Train Loss: 0.1223, Train Acc: 95.38% | Test loss: 0.1170, Test acc: 97.00%
# Epoch: 960 | Train Loss: 0.1182, Train Acc: 95.62% | Test loss: 0.1128, Test acc: 97.00%
# Epoch: 970 | Train Loss: 0.1142, Train Acc: 96.00% | Test loss: 0.1087, Test acc: 97.00%
# Epoch: 980 | Train Loss: 0.1103, Train Acc: 96.38% | Test loss: 0.1046, Test acc: 97.00%
# Epoch: 990 | Train Loss: 0.1064, Train Acc: 96.75% | Test loss: 0.1006, Test acc: 97.50%

# %%
# Predict some
model_0.eval()
with torch.inference_mode():
    y_pred_logits = model_0(X_moon_test).squeeze()
    y_pred = torch.round(torch.sigmoid(y_pred_logits))
y_pred[:10]
# Out:
# tensor([1., 0., 1., 0., 1., 1., 0., 1., 1., 0.], device='cuda:0')

# %%
y_moon_test[:10]
# Out:
# tensor([1., 0., 1., 0., 1., 1., 0., 0., 1., 0.], device='cuda:0')

# %% [markdown]
# ## Plot the Predictions

# %%
from helper_functions import plot_decision_boundary
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(model_0, X_moon_train, y_moon_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(model_0, X_moon_test, y_moon_test)
